# %% [markdown]
# # Get workspace

# %%
from azureml.core import Workspace
ws = Workspace.from_config()
ws
# Out:
# Workspace.create(name='huytung-ws', subscription_id='1f5e877f-48a6-4973-aa3b-ceead3340ce7', resource_group='huytung-rsgroup')

# %%
ws.datasets
# Out:
# {'diabetes file dataset': DatasetRegistration(id='97062e92-e997-4a81-a1e0-81e3adb5af20', name='diabetes file dataset', version=1, description='diabetes files', tags={'format': 'CSV'}), 'diabetes dataset': DatasetRegistration(id='d42f957d-2101-477d-906e-92a5c63fab7e', name='diabetes dataset', version=2, description='diabetes data', tags={'format': 'CSV'})}

# %% [markdown]
# # Get default datastore and upload data to datastore

# %%
from azureml.core import Dataset
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir='../../data',
                        target_path='diabetes-datas',
                        overwrite=True,
                        show_progress=True)
# Out:
# Uploading an estimated of 2 files
# Uploading ../../data\diabetes2.csv
# Uploaded ../../data\diabetes2.csv, 1 files out of an estimated total of 2
# Uploading ../../data\diabetes.csv
# Uploaded ../../data\diabetes.csv, 2 files out of an estimated total of 2
# Uploaded 2 files
# $AZUREML_DATAREFERENCE_2b54bb3e234643b19d662314f257713d

# %% [markdown]
# # Create and register Datasets

# %%
tablular_dataset = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-datas/*.csv'))
tablular_dataset = tablular_dataset.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)

# %% [markdown]
# # Create environment for pipeline

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
env = Environment.get(ws, 'diabetes-pipeline-env')
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.

# %%
from azureml.core import ComputeTarget
pipeline_compute = ComputeTarget(workspace=ws, name='huytungcomputename')
pipeline_compute
# Out:
# {
#   "id": "/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourceGroups/huytung-rsgroup/providers/Microsoft.MachineLearningServices/workspaces/huytung-ws/computes/huytungcomputename",
#   "name": "huytungcomputename",
#   "location": "eastus2",
#   "tags": null,
#   "properties": {
#     "description": null,
#     "computeType": "ComputeInstance",
#     "computeLocation": "eastus2",
#     "resourceId": null,
#     "provisioningErrors": null,
#     "provisioningState": "Succeeded",
#     "properties": {
#       "vmSize": "STANDARD_DS11_V2",
#       "applications": [
#         {
#           "displayName": "Jupyter",
#           "endpointUri": "https://huytungcomputename.eastus2.instances.azureml.ms"
#         },
#         {
#           "displayName": "Jupyter Lab",
#           "endpointUri": "https://huytungcomputename.eastus2.instances.azureml.ms/lab"
#         },
#         {
#           "displayName": "RStudio",
#           "endpointUri": "https://huytungcomputename-8787.eastus2.instances.azureml.ms"
#         }
#       ],
#       "connectivityEndpoints": {
#         "publicIpAddress": "20.75.117.223",
#         "privateIpAddress": "10.0.0.4"
#       },
#       "sshSettings": {
#         "sshPublicAccess": "Disabled",
#         "adminUserName": "azureuser",
#         "adminPublicKey": null,
#         "sshPort": 4000
#       },
#       "personalComputeInstanceSettings": null,
#       "subnet": {
#         "id": null
#       },
#       "errors": []
#     },
#     "status": {
#       "errors": [],
#       "creationTime": "2021-04-25T05:19:56.615114+00:00",
#       "createdBy": {
#         "userObjectId": "beceb2c0-e78f-4733-929f-a3a5cd7b1f46",
#         "userTenantId": "1fd983f3-dc44-42f8-ad66-7972e9d94659",
#         "userName": "Tung Le Huy"
#       },
#       "modifiedTime": "2021-04-25T05:22:43.155746+00:00",
#       "state": "Running",
#       "vmSize": "STANDARD_DS11_V2"
#     }
#   }
# }

# %%
from azureml.core.runconfig import RunConfiguration
# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()
# Use the compute you created above. 
pipeline_run_config.target = pipeline_compute
# Assign the environment to the run configuration
pipeline_run_config.environment = env

# %% [markdown]
# # Create Pipeline

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
# diabetes_ds = ws.datasets.get("diabetes dataset")
diabetes_ds = Dataset.get_by_name(workspace=ws, name='diabetes dataset')

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = './',
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_compute,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = './',
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_compute,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print(pipeline_run.get_portal_url)
print("Pipeline submitted for execution.")
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [deadee62][a458ae20-dc88-4b5b-b37e-cd48499436f4], (This step will run and generate new outputs)
# Created step Train and Register Model [a7bd56d7][2ba72e0b-740b-42ed-bf38-38ad85863e5a], (This step will run and generate new outputs)
# Submitted PipelineRun 8852d7f7-c093-4d73-9457-b4cb04dafc70
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8852d7f7-c093-4d73-9457-b4cb04dafc70?wsid=/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourcegroups/huytung-rsgroup/workspaces/huytung-ws&tid=1fd983f3-dc44-42f8-ad66-7972e9d94659
# <bound method HasRunPortal.get_portal_url of Run(Experiment: mslearn-diabetes-pipeline,
# Id: 8852d7f7-c093-4d73-9457-b4cb04dafc70,
# Type: azureml.PipelineRun,
# Status: Preparing)>
# Pipeline submitted for execution.
# PipelineRunId: 8852d7f7-c093-4d73-9457-b4cb04dafc70
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8852d7f7-c093-4d73-9457-b4cb04dafc70?wsid=/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourcegroups/huytung-rsgroup/workspaces/huytung-ws&tid=1fd983f3-dc44-42f8-ad66-7972e9d94659
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 9a080d77-3925-4def-a419-22de82f9c441
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/9a080d77-3925-4def-a419-22de82f9c441?wsid=/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourcegroups/huytung-rsgroup/workspaces/huytung-ws&tid=1fd983f3-dc44-42f8-ad66-7972e9d94659
# StepRun( Prepare Data ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/04/26 16:47:15 Downloading source code...
# 2021/04/26 16:47:16 Finished downloading source code
# 2021/04/26 16:47:16 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/04/26 16:47:17 Successfully set up Docker network: acb_default_network
# 2021/04/26 16:47:17 Setting up Docker configuration...
# 2021/04/26 16:47:17 Successfully set up Docker configuration
# 2021/04/26 16:47:17 Logging in to registry: 553468aa0d0641b599058c4c963277fd.azurecr.io
# 2021/04/26 16:47:18 Successfully logged into 553468aa0d0641b599058c4c963277fd.azurecr.io
# 2021/04/26 16:47:18 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/04/26 16:47:18 Scanning for dependencies...
# 2021/04/26 16:47:19 Successfully scanned dependencies
# 2021/04/26 16:47:19 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#  ---> c942df5ba5d0
# Step 2/18 : USER root
#  ---> Running in 82b09a28568c
# Removing intermediate container 82b09a28568c
#  ---> a4c887de6934
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 290312103f3f
# Removing intermediate container 290312103f3f
#  ---> 065560cb86f5
# Step 4/18 : WORKDIR /
#  ---> Running in 4659b16c686e
# StepRun( Prepare Data ) Status: Running
# Removing intermediate container 4659b16c686e
#  ---> fda39fa37d73
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> f29ab766d3aa
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in d096666fe1e4
# Removing intermediate container d096666fe1e4
#  ---> 2d81dd032e0f
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> bfbec1b33ff7
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 7dbdfb515603
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########6  |  86%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   2%
# mkl-2019.4           | 204.1 MB  | 4          |   5%
# mkl-2019.4           | 204.1 MB  | 8          |   8%
# mkl-2019.4           | 204.1 MB  | #          |  11%
# mkl-2019.4           | 204.1 MB  | #4         |  15%
# mkl-2019.4           | 204.1 MB  | #7         |  17%
# mkl-2019.4           | 204.1 MB  | #9         |  20%
# mkl-2019.4           | 204.1 MB  | ##2        |  23%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  30%
# mkl-2019.4           | 204.1 MB  | ###3       |  33%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####       |  41%
# mkl-2019.4           | 204.1 MB  | ####4      |  45%
# mkl-2019.4           | 204.1 MB  | ####8      |  49%
# mkl-2019.4           | 204.1 MB  | #####2     |  52%
# mkl-2019.4           | 204.1 MB  | #####5     |  56%
# mkl-2019.4           | 204.1 MB  | ######     |  60%
# mkl-2019.4           | 204.1 MB  | ######4    |  64%
# mkl-2019.4           | 204.1 MB  | ######7    |  68%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######3   |  73%
# mkl-2019.4           | 204.1 MB  | #######6   |  77%
# mkl-2019.4           | 204.1 MB  | #######9   |  79%
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ##4        |  25%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ###5       |  35%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########2  |  82%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 4          |   4%
# qt-5.9.6             | 86.7 MB   | #3         |  13%
# qt-5.9.6             | 86.7 MB   | #9         |  20%
# qt-5.9.6             | 86.7 MB   | ##8        |  28%
# qt-5.9.6             | 86.7 MB   | ###6       |  37%
# qt-5.9.6             | 86.7 MB   | ####5      |  46%
# qt-5.9.6             | 86.7 MB   | #####5     |  56%
# qt-5.9.6             | 86.7 MB   | ######3    |  64%
# qt-5.9.6             | 86.7 MB   | #######2   |  72%
# qt-5.9.6             | 86.7 MB   | ########   |  80%
# qt-5.9.6             | 86.7 MB   | ########7  |  88%
# qt-5.9.6             | 86.7 MB   | #########8 |  98%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ########2  |  82%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##6        |  26%
# scipy-1.5.2          | 18.5 MB   | #####8     |  58%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######5    |  66%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ######     |  61%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ######3    |  64%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | 6          |   7%
# icu-58.2             | 22.7 MB   | ###4       |  34%
# icu-58.2             | 22.7 MB   | ######7    |  68%
# icu-58.2             | 22.7 MB   | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | #####7     |  57%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ##2        |  22%
# pandas-1.1.3         | 10.5 MB   | #########4 |  95%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | 2          |   2%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #3         |  13%
# python-3.6.2         | 27.0 MB   | ####6      |  46%
# python-3.6.2         | 27.0 MB   | #######5   |  76%
# python-3.6.2         | 27.0 MB   | #########6 |  96%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.62084wcz.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.27.0
#   Downloading azureml_defaults-1.27.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.15.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-core~=1.27.0
#   Downloading azureml_core-1.27.0-py3-none-any.whl (2.2 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.27.0
#   Downloading azureml_dataset_runtime-1.27.0-py3-none-any.whl (3.4 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-dataprep-native<34.0.0,>=33.0.0
#   Downloading azureml_dataprep_native-33.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex<1.14.0a,>=1.13.0dev0
#   Downloading azureml_dataprep_rslex-1.13.0-cp36-cp36m-manylinux1_x86_64.whl (9.8 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.62084wcz.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.62084wcz.requirements.txt (line 2)) (1.1.3)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-core~=1.27.0->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.62084wcz.requirements.txt (line 1)) (2.8.1)
# Collecting ruamel.yaml<1.0.0,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-core~=1.27.0->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.62084wcz.requirements.txt (line 1)) (2020.1)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.62084wcz.requirements.txt (line 1)) (1.15.0)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.11.0-py2.py3-none-any.whl (63 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.13.0-py2.py3-none-any.whl (133 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.27.0->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.62084wcz.requirements.txt (line 1)) (2020.6.20)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=726c2c305d7e3480fd44becd342e976d1c5228d35d1beea41169a774081e2074
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=c88b118ac435971056d7df3beed20e76a7b08af3de4de020a96f39ddd1ea0bd5
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=91a259d6facbf5f82ab0fe027cc0136d251fa4c619990bb17647c950b30ff3da
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: pycparser, cffi, cryptography, pyopenssl, backports.weakref, backports.tempfile, jmespath, isodate, urllib3, idna, chardet, requests, oauthlib, requests-oauthlib, msrest, PyJWT, adal, msrestazure, azure-common, azure-mgmt-resource, jeepney, SecretStorage, pyasn1, ndg-httpsclient, ruamel.yaml.clib, ruamel.yaml, zipp, typing-extensions, importlib-metadata, jsonpickle, azure-graphrbac, websocket-client, docker, azure-mgmt-keyvault, azure-mgmt-containerregistry, pathspec, contextlib2, azure-mgmt-authorization, azure-mgmt-storage, azureml-core, configparser, azureml-dataprep-native, msal, azure-core, portalocker, msal-extensions, azure-identity, cloudpickle, azureml-dataprep-rslex, distro, dotnetcore2, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, werkzeug, json-logging-py, applicationinsights, itsdangerous, click, MarkupSafe, Jinja2, flask, dill, liac-arff, azureml-model-management-sdk, gunicorn, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.0.1 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.13.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.27.0 azureml-dataprep-2.15.0 azureml-dataprep-native-33.0.0 azureml-dataprep-rslex-1.13.0 azureml-dataset-runtime-1.27.0 azureml-defaults-1.27.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-4.0.1 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.11.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.4 websocket-client-0.58.0 werkzeug-1.0.1 zipp-3.4.1
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 7dbdfb515603
#  ---> 866fcf243fbb
# Step 9/18 : ENV PATH /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin:$PATH
#  ---> Running in 45c58b657718
# Removing intermediate container 45c58b657718
#  ---> 788c598006cc
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> bd8c4e209442
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 0977e019c7be
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a
#  ---> Running in da37e8481cc4
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container da37e8481cc4
#  ---> 582dbd08facc
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a
#  ---> Running in be40f0f73912
# Removing intermediate container be40f0f73912
#  ---> 09f1400b3414
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib:$LD_LIBRARY_PATH
#  ---> Running in 778a3ddb1c33
# Removing intermediate container 778a3ddb1c33
#  ---> 982c8d370591
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 53027e84d629
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 23f48f7e3f8c
# Removing intermediate container 23f48f7e3f8c
#  ---> 668f2271f29a
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 7a059b1a89ad
# Removing intermediate container 7a059b1a89ad
#  ---> 758545394b76
# Step 18/18 : CMD ["bash"]
#  ---> Running in c08e91971265
# Removing intermediate container c08e91971265
#  ---> ebd12d9fb551
# Successfully built ebd12d9fb551
# Successfully tagged 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# Successfully tagged 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:1
# 2021/04/26 16:52:38 Successfully executed container: acb_step_0
# 2021/04/26 16:52:38 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/04/26 16:52:38 Pushing image: 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:1, attempt 1
# The push refers to repository [553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350]
# 30bfc885b957: Preparing
# 600cc57f63b7: Preparing
# 25fd205bdb0c: Preparing
# 49d046eb68cb: Preparing
# f318ac08c6f3: Preparing
# b595d75230f2: Preparing
# 0642b84f560c: Preparing
# 5c53925757ee: Preparing
# fc689a2aa575: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# b595d75230f2: Waiting
# 0642b84f560c: Waiting
# 5c53925757ee: Waiting
# fc689a2aa575: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 30bfc885b957: Pushed
# 25fd205bdb0c: Pushed
# 600cc57f63b7: Pushed
# 49d046eb68cb: Pushed
# b595d75230f2: Pushed
# 0642b84f560c: Pushed
# fc689a2aa575: Pushed
# 5c53925757ee: Pushed
# 3f3f8889d538: Pushed
# 420340de7040: Pushed
# c3d9b0d7dd4c: Pushed
# 18c9012f327d: Pushed
# 0d34930f20d5: Pushed
# 5276d2b930fc: Pushed
# e6feec0db89a: Pushed
# 697949baa658: Pushed
# 4441896e1280: Pushed
# a64fe594a899: Pushed
# 935c56d8b3f9: Pushed
# e4a0bf630548: Pushed
# f318ac08c6f3: Pushed
# 1: digest: sha256:161300a4b52fa25d1f88ee27069beac80d9acaffc54d9f3a71cc98e549fa6bdd size: 4721
# 2021/04/26 16:55:39 Successfully pushed image: 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:1
# 2021/04/26 16:55:39 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/04/26 16:55:39 Pushing image: 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest, attempt 1
# The push refers to repository [553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350]
# 30bfc885b957: Preparing
# 600cc57f63b7: Preparing
# 25fd205bdb0c: Preparing
# 49d046eb68cb: Preparing
# f318ac08c6f3: Preparing
# b595d75230f2: Preparing
# 0642b84f560c: Preparing
# 5c53925757ee: Preparing
# fc689a2aa575: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# b595d75230f2: Waiting
# 0642b84f560c: Waiting
# 5c53925757ee: Waiting
# fc689a2aa575: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# 697949baa658: Waiting
# e6feec0db89a: Waiting
# 935c56d8b3f9: Waiting
# f318ac08c6f3: Layer already exists
# 25fd205bdb0c: Layer already exists
# 30bfc885b957: Layer already exists
# 49d046eb68cb: Layer already exists
# b595d75230f2: Layer already exists
# 0642b84f560c: Layer already exists
# 600cc57f63b7: Layer already exists
# 5c53925757ee: Layer already exists
# fc689a2aa575: Layer already exists
# c3d9b0d7dd4c: Layer already exists
# 3f3f8889d538: Layer already exists
# 4441896e1280: Layer already exists
# a64fe594a899: Layer already exists
# 420340de7040: Layer already exists
# 0d34930f20d5: Layer already exists
# 18c9012f327d: Layer already exists
# e6feec0db89a: Layer already exists
# 5276d2b930fc: Layer already exists
# e4a0bf630548: Layer already exists
# 697949baa658: Layer already exists
# 935c56d8b3f9: Layer already exists
# latest: digest: sha256:161300a4b52fa25d1f88ee27069beac80d9acaffc54d9f3a71cc98e549fa6bdd size: 4721
# 2021/04/26 16:55:45 Successfully pushed image: 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# 2021/04/26 16:55:45 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 319.399150)
# 2021/04/26 16:55:45 Populating digests for step ID: acb_step_0...
# 2021/04/26 16:55:49 Successfully populated digests for step ID: acb_step_0
# 2021/04/26 16:55:49 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 181.166614)
# 2021/04/26 16:55:49 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.438352)
# 2021/04/26 16:55:49 The following dependencies were found:
# 2021/04/26 16:55:49
# - image:
#     registry: 553468aa0d0641b599058c4c963277fd.azurecr.io
#     repository: azureml/azureml_443e6f417ae4fd3295e21acd32219350
#     tag: latest
#     digest: sha256:161300a4b52fa25d1f88ee27069beac80d9acaffc54d9f3a71cc98e549fa6bdd
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
# - image:
#     registry: 553468aa0d0641b599058c4c963277fd.azurecr.io
#     repository: azureml/azureml_443e6f417ae4fd3295e21acd32219350
#     tag: "1"
#     digest: sha256:161300a4b52fa25d1f88ee27069beac80d9acaffc54d9f3a71cc98e549fa6bdd
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
#
#
# Run ID: ch6 was successful after 8m36s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_e18f985b2a2a85421be77841684473bc3ce38caa77df5fd10c25655aeba88109_d.txt
# ========================================================================================================================
# 2021-04-26T16:56:18Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9a080d77-3925-4def-a419-22de82f9c441/mounts/workspaceblobstore
# 2021-04-26T16:56:19Z Starting output-watcher...
# 2021-04-26T16:56:19Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-04-26T16:56:20Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-26T16:56:20Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_443e6f417ae4fd3295e21acd32219350
# 4007a89234b4: Already exists
# 5dfa26c6b9c9: Already exists
# 0ba7bf18aa40: Already exists
# 4c6ec688ebe3: Already exists
# 574f361512d6: Already exists
# db4d1e2d7079: Already exists
# e544ee0f522d: Already exists
# c655136086be: Already exists
# 2ec37f44090c: Already exists
# 5fba3bd4a2c4: Already exists
# 7e0ea9d0a1ab: Already exists
# da005f826951: Already exists
# f801c5996898: Pulling fs layer
# d001a5ff423f: Pulling fs layer
# e2360f8cc23b: Pulling fs layer
# 6bf2eba83a9f: Pulling fs layer
# 69d1ce99a0f8: Pulling fs layer
# b58d9a8bc1dd: Pulling fs layer
# 8ba6bc913db2: Pulling fs layer
# 9c7ec463d842: Pulling fs layer
# 8cb42098f891: Pulling fs layer
# 6bf2eba83a9f: Waiting
# 69d1ce99a0f8: Waiting
# b58d9a8bc1dd: Waiting
# 8ba6bc913db2: Waiting
# 9c7ec463d842: Waiting
# 8cb42098f891: Waiting
# f801c5996898: Verifying Checksum
# f801c5996898: Download complete
# d001a5ff423f: Verifying Checksum
# d001a5ff423f: Download complete
# e2360f8cc23b: Download complete
# 6bf2eba83a9f: Verifying Checksum
# 6bf2eba83a9f: Download complete
# b58d9a8bc1dd: Verifying Checksum
# b58d9a8bc1dd: Download complete
# 8ba6bc913db2: Verifying Checksum
# 8ba6bc913db2: Download complete
# f801c5996898: Pull complete
# 8cb42098f891: Verifying Checksum
# 8cb42098f891: Download complete
# 9c7ec463d842: Verifying Checksum
# 9c7ec463d842: Download complete
# d001a5ff423f: Pull complete
# e2360f8cc23b: Pull complete
# 6bf2eba83a9f: Pull complete
# 69d1ce99a0f8: Verifying Checksum
# 69d1ce99a0f8: Download complete
# 69d1ce99a0f8: Pull complete
# b58d9a8bc1dd: Pull complete
# 8ba6bc913db2: Pull complete
# 9c7ec463d842: Pull complete
# 8cb42098f891: Pull complete
# Digest: sha256:161300a4b52fa25d1f88ee27069beac80d9acaffc54d9f3a71cc98e549fa6bdd
# Status: Downloaded newer image for 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# 553468aa0d0641b599058c4c963277fd.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# 2021-04-26T16:56:56Z Check if container 9a080d77-3925-4def-a419-22de82f9c441 already exist exited with 0,
#
# 90c003a5455b0e1f7050974aac150b72b78ee1aee2457bddc830d3f87cc0e3ac
# 2021-04-26T16:57:06Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-26T16:57:06Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-693ae7a5002f4b7f454309147b37e84f-e9c8f8ca0169a8ed-01 -sshRequired=false]
# 2021/04/26 16:57:06 Starting App Insight Logger for task:  containerSetup
# 2021/04/26 16:57:06 Version: 3.0.01566.0002 Branch: .SourceBranch Commit: c9b5129
# 2021/04/26 16:57:06 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/26 16:57:06 Starting infiniband setup
# 2021/04/26 16:57:06 VMSize: standard_ds11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/04/26 16:57:06 VMSize: standard_ds11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021-04-26T16:57:06Z VMSize: standard_ds11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/04/26 16:57:06 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/26 16:57:06 Not setting up Infiniband in Container
# 2021/04/26 16:57:06 Not setting up Infiniband in Container
# 2021-04-26T16:57:06Z Not setting up Infiniband in Container
# 2021/04/26 16:57:06 sshd inside container not required for job, skipping setup.
# 2021/04/26 16:57:07 All App Insights Logs was send successfully
# 2021/04/26 16:57:07 App Insight Client has already been closed
# 2021/04/26 16:57:07 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-04-26T16:57:07Z Starting docker container succeeded.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/04/26 16:57:12 Starting App Insight Logger for task:  runTaskLet
# 2021/04/26 16:57:12 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/04/26 16:57:12 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-04-26T16:57:12.457574] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['prep_diabetes.py', '--input-data', 'd42f957d-2101-477d-906e-92a5c63fab7e', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9a080d77-3925-4def-a419-22de82f9c441/mounts/workspaceblobstore/azureml/9a080d77-3925-4def-a419-22de82f9c441/prepped_data_folder'])
# Script type = None
# [2021-04-26T16:57:13.745087] Entering Run History Context Manager.
# [2021-04-26T16:57:14.986651] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9a080d77-3925-4def-a419-22de82f9c441/mounts/workspaceblobstore/azureml/9a080d77-3925-4def-a419-22de82f9c441
# [2021-04-26T16:57:14.993614] Preparing to call script [prep_diabetes.py] with arguments:['--input-data', 'd42f957d-2101-477d-906e-92a5c63fab7e', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9a080d77-3925-4def-a419-22de82f9c441/mounts/workspaceblobstore/azureml/9a080d77-3925-4def-a419-22de82f9c441/prepped_data_folder']
# [2021-04-26T16:57:14.993667] After variable expansion, calling script [prep_diabetes.py] with arguments:['--input-data', 'd42f957d-2101-477d-906e-92a5c63fab7e', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9a080d77-3925-4def-a419-22de82f9c441/mounts/workspaceblobstore/azureml/9a080d77-3925-4def-a419-22de82f9c441/prepped_data_folder']
#
# Loading Data...
# 2021/04/26 16:57:17 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# Saving Data...
#
#
# [2021-04-26T16:57:29.392301] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 1.0616552829742432 seconds
# [2021-04-26T16:57:31.519797] Finished context manager injector.
#
# Streaming azureml-logs/75_job_post-tvmps_e18f985b2a2a85421be77841684473bc3ce38caa77df5fd10c25655aeba88109_d.txt
# ===============================================================================================================
# [2021-04-26T16:57:37.140567] Entering job release
# [2021-04-26T16:57:38.134774] Starting job release
# [2021-04-26T16:57:38.135745] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 326
# [2021-04-26T16:57:38.136411] job release stage : upload_datastore starting...
# [2021-04-26T16:57:38.137007] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-26T16:57:38.141812] job release stage : copy_batchai_cached_logs starting...
# ...
# >>>   2021/04/26 16:58:26 Check if container 9bb67af3-5a2f-4add-a44e-f0adb7d60462 already exist exited with 0,
# >>>
# >>>   2021/04/26 16:58:26 Check if container 9bb67af3-5a2f-4add-a44e-f0adb7d60462 already exist exited with 0,
# >>>
# >>>   2021/04/26 16:58:26 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/26 16:58:26 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/26 16:58:26 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-8d006583d15637444a7c8ed69fc9d30b-aa7b380b28d980aa-01 -sshRequired=false]
# >>>   2021/04/26 16:58:26 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-8d006583d15637444a7c8ed69fc9d30b-aa7b380b28d980aa-01 -sshRequired=false]
# >>>   2021/04/26 16:58:27 Container ssh is not required for job type.
# >>>   2021/04/26 16:58:27 Starting docker container succeeded.
# >>>   2021/04/26 16:58:27 Starting docker container succeeded.
# >>>   2021/04/26 16:58:27 Disk space after starting docker container: 26241MB
# >>>   2021/04/26 16:58:27 Begin execution of runSpecialJobTask
# >>>   2021/04/26 16:58:27 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/azureml_compute_logs
# >>>   2021/04/26 16:58:27 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"ae63411f-69d8-4d29-bd3c-266992af8f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/26 16:58:27 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/azureml_compute_logs/65_job_prep-tvmps_e18f985b2a2a85421be77841684473bc3ce38caa77df5fd10c25655aeba88109_d.txt
# >>>   2021/04/26 16:58:27 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/azureml_compute_logs/65_job_prep-tvmps_e18f985b2a2a85421be77841684473bc3ce38caa77df5fd10c25655aeba88109_d.txt
# >>>   2021/04/26 16:58:27 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/1fbe591a-860f-4a48-895a-f44fc056603b/job-1/9bb67af3-5a2f-4add-a_71848389-1f09-4391-858d-a00a400b77c8/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462;/azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"ae63411f-69d8-4d29-bd3c-266992af8f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/26 16:58:27 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/04/26 16:58:27 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-8d006583d15637444a7c8ed69fc9d30b-3c49bce63eefea44-01 -t 9bb67af3-5a2f-4add-a44e-f0adb7d60462 bash -c source /etc/bash.bashrc; PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/1fbe591a-860f-4a48-895a-f44fc056603b/job-1/9bb67af3-5a2f-4add-a_71848389-1f09-4391-858d-a00a400b77c8/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462;/azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/huytung-ws/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462/mounts/workspaceblobstore/azureml/9bb67af3-5a2f-4add-a44e-f0adb7d60462-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"ae63411f-69d8-4d29-bd3c-266992af8f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/26 16:58:28 Attempt 1 of http call to https://eastus2.api.azureml.ms/history/v1.0/private/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourceGroups/huytung-rsgroup/providers/Microsoft.MachineLearningServices/workspaces/huytung-ws/runs/9bb67af3-5a2f-4add-a44e-f0adb7d60462/spans
# >>>   2021/04/26 16:58:32 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:28.099046] Entering job preparation.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:29.592202] Starting job preparation.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:29.592243] Extracting the control code.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:29.612654] fetching and extracting the control code on master node.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:29.612727] Starting extract_project.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:29.612823] Starting to extract zip file.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.237876] Finished extracting zip file.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.384349] Using urllib.request Python 3.0 or later
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.384429] Start fetching snapshots.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.384487] Start fetching snapshot.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.384514] Retrieving project from snapshot: ae63411f-69d8-4d29-bd3c-266992af8f1d
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 43
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.704848] Finished fetching snapshot.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.704883] Finished fetching snapshots.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.704893] Finished extract_project.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.716713] Finished fetching and extracting the control code.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.722130] downloadDataStore - Download from datastores if requested.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.723227] Start run_history_prep.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:30.784581] Entering context manager injector.
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: Acquired lockfile /tmp/9bb67af3-5a2f-4add-a44e-f0adb7d60462-datastore.lock to downloading input data references
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:31.244237] downloadDataStore completed
# >>>   2021/04/26 16:58:32 runSpecialJobTask: preparation: [2021-04-26T16:58:31.247485] Job preparation is complete.
# >>>   2021/04/26 16:58:32 Execution of runSpecialJobTask completed
# >>>   2021/04/26 16:58:32 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/04/26 16:58:32 Process Exiting with Code:  0
# >>>   2021/04/26 16:58:32 All App Insights Logs was send successfully
# >>>
# 2021-04-26T16:58:32Z 127.0.0.1 slots=2 max-slots=2
# 2021-04-26T16:58:33Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_e18f985b2a2a85421be77841684473bc3ce38caa77df5fd10c25655aeba88109_d.txt
# ===============================================================================================================
# [2021-04-26T16:58:47.835100] Entering job release
# [2021-04-26T16:58:48.885508] Starting job release
# [2021-04-26T16:58:48.889882] Logging experiment finalizing status in history service.
# [2021-04-26T16:58:48.890073] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 147
# [2021-04-26T16:58:48.890517] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-26T16:58:48.890553] job release stage : execute_job_release starting...
# [2021-04-26T16:58:48.890883] job release stage : copy_batchai_cached_logs starting...
# [2021-04-26T16:58:48.890920] job release stage : copy_batchai_cached_logs completed...
# [2021-04-26T16:58:48.900669] Entering context manager injector.
# [2021-04-26T16:58:48.914932] job release stage : upload_datastore completed...
# [2021-04-26T16:58:49.084162] job release stage : send_run_telemetry starting...
# [2021-04-26T16:58:49.100669] job release stage : execute_job_release completed...
# [2021-04-26T16:58:49.304153] get vm size and vm region successfully.
# [2021-04-26T16:58:49.489349] get compute meta data successfully.
# [2021-04-26T16:58:49.618651] post artifact meta request successfully.
# [2021-04-26T16:58:49.646027] upload compute record artifact successfully.
# [2021-04-26T16:58:49.646123] job release stage : send_run_telemetry completed...
# [2021-04-26T16:58:49.646626] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '9bb67af3-5a2f-4add-a44e-f0adb7d60462', 'target': 'huytungcomputename', 'status': 'Completed', 'startTimeUtc': '2021-04-26T16:58:23.926326Z', 'endTimeUtc': '2021-04-26T16:58:57.22685Z', 'properties': {'ContentSnapshotId': 'ae63411f-69d8-4d29-bd3c-266992af8f1d', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '2ba72e0b-740b-42ed-bf38-38ad85863e5a', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'a7bd56d7', 'azureml.pipelinerunid': '8852d7f7-c093-4d73-9457-b4cb04dafc70', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'huytungcomputename', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/9a080d77-3925-4def-a419-22de82f9c441/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.27.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_28b0d742a4cb5c02a5befb218632cd1a'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_e18f985b2a2a85421be77841684473bc3ce38caa77df5fd10c25655aeba88109_d.txt': 'https://huytungws8293462828.blob.core.windows.net/azureml/ExperimentRun/dcid.9bb67af3-5a2f-4add-a44e-f0adb7d60462/azureml-logs/55_azureml-execution-tvmps_e18f985b2a2a85421be77841684473bc3ce38caa77df5fd10c25655aeba88109_d.txt?sv=2019-02-02&sr=b&sig=XIiYZdRa23n7oDnfPpJTnjaf7N8OKCupjFAEmj%2BXrqQ%3D&st=2021-04-26T16%3A48%3A53Z&se=2021-04-27 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '8852d7f7-c093-4d73-9457-b4cb04dafc70', 'status': 'Completed', 'startTimeUtc': '2021-04-26T16:46:57.448074Z', 'endTimeUtc': '2021-04-26T16:59:05.576054Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://huytungws8293462828.blob.core.windows.net/azureml/ExperimentRun/dcid.8852d7f7-c093-4d73-9457-b4cb04dafc70/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=tULm7h%2BipnFavUxIOSAoMbtuBm9SpVejkkRs6kI2zwM%3D&st=2021-04-26T16%3A37%3A27Z&se=2021-04-27T00%3A47%3A27Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://huytungws8293462828.blob.core.windows.net/azureml/ExperimentRun/dcid.8852d7f7-c093-4d73-9457-b4cb04dafc70/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=nJSeLRttcHOU7lXsaSY5GPnXqkIHXwOLwUOlso6Ma08%3D&st=2021-04-26T16%3A37%3A28Z&se=2021-04-27T00%3A47%3A28Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://huytungws8293462828.blob.core.windows.net/azureml/ExperimentRun/dcid.8852d7f7-c093-4d73-9457-b4cb04dafc70/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=7Gx15tyI2YE5xnUiQ6%2BD0LYt5SIx2CCX2dSqnwaWXkY%3D&st=2021-04-26T16%3A37%3A28Z&se=2021-04-27T00%3A47%3A28Z&sp=r'}, 'submittedBy': 'Tung Le Huy'}
# 'Finished'

# %% [markdown]
# # Get results

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8984444444444445
# 	 AUC : 0.8834267090544071
# 	 ROC : aml://artifactId/ExperimentRun/dcid.9bb67af3-5a2f-4add-a44e-f0adb7d60462/ROC_1619456317.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 2
# 	 Training context : Pipeline
# 	 AUC : 0.8834267090544071
# 	 Accuracy : 0.8984444444444445
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8484437036668493
# 	 Accuracy : 0.774

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: e4dfe6e8-e005-4b2f-90f8-c5b247df16c0,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourceGroups/huytung-rsgroup/providers/Microsoft.MachineLearningServices/workspaces/huytung-ws/PipelineRuns/PipelineSubmit/e4dfe6e8-e005-4b2f-90f8-c5b247df16c0)

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourceGroups/huytung-rsgroup/providers/Microsoft.MachineLearningServices/workspaces/huytung-ws/PipelineRuns/PipelineSubmit/e4dfe6e8-e005-4b2f-90f8-c5b247df16c0

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()
run_id
# Out:
# {'Description': None,
#  'Status': {'StatusCode': 0,
#   'StatusDetail': None,
#   'CreationTime': '2021-04-26T17:06:19.4286714Z',
#   'EndTime': None},
#  'GraphId': 'a15ae2a5-c7c1-438c-875c-c774dc914a0d',
#  'IsSubmitted': False,
#  'HasErrors': False,
#  'HasWarnings': False,
#  'UploadState': 0,
#  'ParameterAssignments': {},
#  'DataPathAssignments': {},
#  'DataSetDefinitionValueAssignments': {},
#  'RunHistoryExperimentName': 'mslearn-diabetes-pipeline',
#  'PipelineId': 'e4dfe6e8-e005-4b2f-90f8-c5b247df16c0',
#  'RunSource': 'Unavailable',
#  'RunType': 0,
#  'TotalRunSteps': 2,
#  'ScheduleId': None,
#  'RunUrl': 'https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/ff9e9ee4-1eec-426d-abdb-81eab3b71deb?tid=1fd983f3-dc44-42f8-ad66-7972e9d94659&wsid=/subscriptions/1f5e877f-48a6-4973-aa3b-ceead3340ce7/resourcegroups/huytung-rsgroup/workspaces/huytung-ws',
#  'tags': {},
#  'StepTags': {},
#  'Properties': {},
#  'StepProperties': {},
#  'CreatedBy': {'UserObjectId': 'beceb2c0-e78f-4733-929f-a3a5cd7b1f46',
#   'UserTenantId': '1fd983f3-dc44-42f8-ad66-7972e9d94659',
#   'UserName': 'Tung Le Huy'},
#  'EntityStatus': 0,
#  'Id': 'ff9e9ee4-1eec-426d-abdb-81eab3b71deb',
#  'Etag': '"2d00676a-0000-0200-0000-6086f30b0000"',
#  'CreatedDate': '2021-04-26T17:06:19.4289293Z',
#  'LastModifiedDate': '2021-04-26T17:06:19.4289293Z'}
